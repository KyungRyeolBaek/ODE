# %% [markdown]
# Module import

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# %% [markdown]
# Solve the following initial value differential equation $$ y'=\lambda y,  \quad  y(0)=y_0$$

# %% [markdown]
# Fuction Define

# %%
# analysis 함수 
def anal(x, lamb):
    return np.exp(lamb*x)

# n : w 개수, w : weight
def y(x, w, n = 4):
    y = 1         # y = 1 + w1*(x) + w2*(x**2) + w3*(x**3) + w4*(x**4)
    for i in range(1, n+1):
        y += w[i-1]*(x**i)
    
    return y

def yprime(x, w, n = 4):
    yprime = 0    # yprime = w1 + 2*w2*x + 3*w3*(x**2) + 4*w4*(x**3)
    for i in range(1, n + 1):
        yprime += i*w[i-1]*(x**(i-1))

    return yprime

def f(y, lamb):
    return lamb*y

# %% [markdown]
# Parameter

# %%
# 최대 x 범위 : 0 <= x < x_max, lambda 값
x_max = 1
x = tf.Variable(np.array([[i/100] for i in range(0, x_max * 100, 1)], dtype = np.float32))
lamb = -2

# 차수, weight 개수
n = 4
w = tf.Variable(tf.random.normal(shape=(n,), dtype=tf.float32), trainable=True) # w = [weight1, weight2, weight3, weight4]

# 변화 w 값, loss 저장
w_trace = []
w_trace.append(w.numpy())
loss_trace = []

#  학습률 조정
learning_rate = 0.01
# EPOCH = 100

# 원하는 loss 값에 도달할 때 까지 Epoch 횟수 올리기
Epoch = 0
target_loss = 0.00001

# %% [markdown]
# Train

# %%
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
from collections import deque


# 학습 과정
while True:
    Epoch += 1
    dq = deque([1,2,3], 3)
    for x_unit in x:
        with tf.GradientTape() as tape:
            # 예측 값
            predict = f(y(x_unit, w, n), lamb)
            loss = tf.math.sqrt(tf.square(predict - yprime(x_unit, w, n)))
            loss_trace.append(loss.numpy())
            dq.append(float(loss))
            # # 오차
            w_trace.append(w.numpy())
            # w = tf.Variable(w - learning_rate*gradients)
        if float(loss) < target_loss:
            break
        gradients = tape.gradient(loss, w)
        optimizer.apply_gradients(zip([gradients], [w]))
    if float(loss) < target_loss and dq[0] == dq[2]:
            break
    if Epoch % 1000 == 0:
        # print('Epoch : {}, Loss : {:.4f}'.format(Epoch, loss))
        print(Epoch, loss)
# Out:
# 1000 tf.Tensor([0.04489261], shape=(1,), dtype=float32)
# 2000 tf.Tensor([0.05460611], shape=(1,), dtype=float32)
# 3000 tf.Tensor([0.05262086], shape=(1,), dtype=float32)
# 4000 tf.Tensor([0.04249704], shape=(1,), dtype=float32)
# 5000 tf.Tensor([0.01134318], shape=(1,), dtype=float32)
# 6000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 7000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 8000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 9000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 10000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 11000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 12000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 13000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 14000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 15000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 16000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 17000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 18000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 19000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 20000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 21000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 22000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 23000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 24000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 25000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 26000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 27000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 28000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 29000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 30000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 31000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 32000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 33000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 34000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 35000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 36000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 37000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 38000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 39000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 40000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 41000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 42000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
#
 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 394000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 395000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 396000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 397000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 398000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 399000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 400000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 401000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 402000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 403000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 404000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 405000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 406000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 407000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 408000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 409000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 410000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 411000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 412000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 413000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 414000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 415000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 416000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 417000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 418000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 419000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 420000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 421000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 422000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 423000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 424000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 425000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 426000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 427000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 428000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 429000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 430000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 431000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 432000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 433000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 434000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 435000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 436000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 437000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 438000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 439000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 440000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 441000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 442000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 443000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 444000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 445000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 446000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 447000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 448000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 449000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 450000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 451000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 452000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 453000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 454000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 455000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 456000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 457000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 458000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 459000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 460000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 461000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 462000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 463000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 464000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 465000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 466000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 467000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 468000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 469000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 470000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 471000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 472000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 473000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 474000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 475000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 476000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 477000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 478000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 479000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 480000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 481000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 482000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 483000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 484000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 485000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 486000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 487000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 488000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 489000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 490000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 491000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 492000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 493000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 494000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 495000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 496000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 497000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 498000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 499000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 500000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 501000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 502000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 503000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 504000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 505000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 506000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 507000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 508000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 509000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 510000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 511000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 512000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 513000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 514000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 515000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 516000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 517000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 518000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 519000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 520000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 521000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 522000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 523000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 524000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# 525000 tf.Tensor([1.1920929e-06], shape=(1,), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\kyungryeol\github\ODE\ODE\expansion220802.ipynb 셀 9 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=8'>9</a> for x_unit in x:
#      <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=9'>10</a>     with tf.GradientTape() as tape:
#      <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=10'>11</a>         # 예측 값
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=11'>12</a>         predict = f(y(x_unit, w, n), lamb)
#      <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=12'>13</a>         loss = tf.math.sqrt(tf.square(predict - yprime(x_unit, w, n)))
#      <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=13'>14</a>         loss_trace.append(loss.numpy())
#
# c:\Users\kyungryeol\github\ODE\ODE\expansion220802.ipynb 셀 9 in y(x, w, n)
#       <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=6'>7</a> y = 1         # y = 1 + w1*(x) + w2*(x**2) + w3*(x**3) + w4*(x**4)
#       <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=7'>8</a> for i in range(1, n+1):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=8'>9</a>     y += w[i-1]*(x**i)
#      <a href='vscode-notebook-cell:/c%3A/Users/kyungryeol/github/ODE/ODE/expansion220802.ipynb#ch0000011?line=10'>11</a> return y
#
# File c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\tensorflow\python\ops\array_ops.py:1351, in _SliceHelperVar(var, slice_spec)
#    1308 def _SliceHelperVar(var, slice_spec):
#    1309   """Creates a slice helper object given a variable.
#    1310
#    1311   This allows creating a sub-tensor from part of the current contents
#    (...)
#    1348
#    1349   """
# -> 1351   return _slice_helper(var.value(), slice_spec, var)
#
# File c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\tensorflow\python\ops\array_ops.py:1097, in _slice_helper(tensor, slice_spec, var)
#    1095   var_empty = constant([], dtype=dtypes.int32)
#    1096   packed_begin = packed_end = packed_strides = var_empty
# -> 1097 return strided_slice(
#    1098     tensor,
#    1099     packed_begin,
#    1100     packed_end,
#    1101     packed_strides,
#    1102     begin_mask=begin_mask,
#    1103     end_mask=end_mask,
#    1104     shrink_axis_mask=shrink_axis_mask,
#    1105     new_axis_mask=new_axis_mask,
#    1106     ellipsis_mask=ellipsis_mask,
#    1107     var=var,
#    1108     name=name)
#
# File c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\tensorflow\python\ops\array_ops.py:1270, in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1267 if strides is None:
#    1268   strides = ones_like(begin)
# -> 1270 op = gen_array_ops.strided_slice(
#    1271     input=input_,
#    1272     begin=begin,
#    1273     end=end,
#    1274     strides=strides,
#    1275     name=name,
#    1276     begin_mask=begin_mask,
#    1277     end_mask=end_mask,
#    1278     ellipsis_mask=ellipsis_mask,
#    1279     new_axis_mask=new_axis_mask,
#    1280     shrink_axis_mask=shrink_axis_mask)
#    1282 parent_name = name
#    1284 if var is not None:
#
# File c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:10664, in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10662 if tld.is_eager:
#   10663   try:
# > 10664     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   10665       _ctx, "StridedSlice", name, input, begin, end, strides, "begin_mask",
#   10666       begin_mask, "end_mask", end_mask, "ellipsis_mask", ellipsis_mask,
#   10667       "new_axis_mask", new_axis_mask, "shrink_axis_mask", shrink_axis_mask)
#   10668     return _result
#   10669   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# weight 값 출력

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_title('Weight & Epoch in x')
ax.set_xlabel('Epoch in x')
ax.set_ylabel('Weight')
ax.plot(w_trace, label = ['w1', 'w2', 'w3', 'w4'])
ax.tick_params(labelsize=10)
ax.legend(fontsize=10)
ax.grid()
# Out:
# c:\Users\kyungryeol\Anaconda3\envs\ODE\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.set_title('Loss & Epoch in x')
ax.set_xlabel('Epoch in x')
ax.set_ylabel('Loss')
ax.plot(loss_trace, label = 'loss')
ax.tick_params(labelsize=10)
ax.legend(fontsize=20)
ax.grid()

# %%
fig, ax = plt.subplots(figsize=(7, 7))
ax.set_title('Analysis & f(lambda*y) & Error')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.plot(anal(x,lamb), label = 'analysis')
ax.plot(y(x, w, n), label = 'y')
ax.plot(y(x, w, n) - anal(x,lamb), label = 'error')
ax.tick_params(labelsize=10)
ax.legend(fontsize=20)
ax.grid()

# %%
np.exp(lamb*1)
# Out:
# 0.1353352832366127

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(y(x, w, n) - anal(x,lamb), label = 'error')
ax.tick_params(labelsize=10)
ax.legend(fontsize=20)
ax.grid()

# %%
x = tf.Variable([0.01*n for n in range(200)], dtype = tf.float32)
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(anal(x,lamb), label = 'analysis')
ax.plot(y(x, w, n), label = 'y')
ax.plot(y(x, w, n) - anal(x,lamb), label = 'error')
ax.tick_params(labelsize=10)
ax.legend(fontsize=20)
ax.grid()

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(y(x, w, n) - anal(x,lamb), label = 'error')
ax.tick_params(labelsize=10)
ax.legend(fontsize=20)
ax.grid()

# %%
# 2022.07.20
# 에러 그래프 부분 보강
# epoch 늘려서 학습 결과 찾기
# w 값 
# w1 = lambda와 비슷하게 -2
# w2 = 2
# w3 = -1
# w4 = 0.5
# layer 구조 확인

# %%
print(Epoch)
# Out:
# 525662

# %%
print(loss)
# Out:
# tf.Tensor([9.4771385e-06], shape=(1,), dtype=float32)
